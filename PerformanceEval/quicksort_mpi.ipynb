# %%
import sys
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
sorted_type = "random"
algorithm = "Quicksort"
implementation = "MPI"

#file_path = "../MergeSort/MPI/dataFiles/random/*.cali"

file_path = f"dataFiles/{implementation}/{algorithm}/{sorted_type}/*.cali"
# file_path = "../quicksort/mpi/cali/2^16/cali/*.cali"
# file_path = f"dataFiles/{implementation}/{algorithm}/2^18/*.cali"
print(file_path)

all_files = glob(file_path)
print(all_files)

tk = th.Thicket.from_caliperreader(all_files)
# Out:
# dataFiles/MPI/Quicksort/random/*.cali
# ['dataFiles/MPI/Quicksort/random\\p2-a1048576-o0.cali', 'dataFiles/MPI/Quicksort/random\\p2-a262144-o0.cali', 'dataFiles/MPI/Quicksort/random\\p2-a65536-o0.cali']

# %%
print(tk.dataframe.keys())
tk.dataframe
# Out:
# Index(['nid', 'spot.channel', 'Min time/rank', 'Max time/rank',
#        'Avg time/rank', 'Total time', 'Variance time/rank', 'name'],
#       dtype='object')
#                                                               nid  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              5969722       1
#                                                   531148905     1
#                                                   2175685273    1
# {'name': 'comm', 'type': 'function'}              5969722       3
#                                                   531148905     3
#                                                   2175685273    3
# {'name': 'MPI_Barrier', 'type': 'function'}       5969722       4
#                                                   531148905     4
#                                                   2175685273    4
# {'name': 'comm_large', 'type': 'function'}        5969722       7
#                                                   531148905     7
#                                                   2175685273    7
# {'name': 'MPI_Recv', 'type': 'function'}          5969722      11
#                                                   531148905    11
#                                                   2175685273   11
# {'name': 'MPI_Scatter', 'type': 'function'}       5969722       8
#                                                   531148905     8
#                                                   2175685273    8
# {'name': 'MPI_Send', 'type': 'function'}          5969722      14
#                                                   531148905    14
#                                                   2175685273   14
# {'name': 'comm_small', 'type': 'function'}        5969722       5
#                                                   531148905     5
#                                                   2175685273    5
# {'name': 'MPI_Bcast', 'type': 'function'}         5969722       6
#                                                   531148905     6
#                                                   2175685273    6
# {'name': 'comp', 'type': 'function'}              5969722       9
#                                                   531148905     9
#                                                   2175685273    9
# {'name': 'comp_large', 'type': 'function'}        5969722      10
#                                                   531148905    10
#                                                   2175685273   10
# {'name': 'comp_small', 'type': 'function'}        5969722      12
#                                                   531148905    12
#                                                   2175685273   12
# {'name': 'correctness_check', 'type': 'function'} 5969722      13
#                                                   531148905    13
#                                                   2175685273   13
# {'name': 'data_init', 'type': 'function'}         5969722       2
#                                                   531148905     2
#                                                   2175685273    2
#
#                                                                spot.channel  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              5969722     regionprofile
#                                                   531148905   regionprofile
#                                                   2175685273  regionprofile
# {'name': 'comm', 'type': 'function'}              5969722     regionprofile
#                                                   531148905   regionprofile
#                                                   2175685273  regionprofile
# {'name': 'MPI_Barrier', 'type': 'function'}       5969722     regionprofile
#                                                   531148905   regionprofile
#                                                   2175685273  regionprofile
# {'name': 'comm_large', 'type': 'function'}        5969722     regionprofile
#                                                   531148905   regionprofile
#                                                   2175685273  regionprofile
# {'name': 'MPI_Recv', 'type': 'function'}          5969722     regionprofile
#                                                   531148905   regionprofile
#                                                   2175685273  regionprofile
# {'name': 'MPI_Scatter', 'type': 'function'}       5969722     regionprofile
#                                                   531148905   regionprofile
#                                                   2175685273  regionprofile
# {'name': 'MPI_Send', 'type': 'function'}          5969722     regionprofile
#                                                   531148905   regionprofile
#                                                   2175685273  regionprofile
# {'name': 'comm_small', 'type': 'function'}        5969722     regionprofile
#                                                   531148905   regionprofile
#                                                   2175685273  regionprofile
# {'name': 'MPI_Bcast', 'type': 'function'}         5969722     regionprofile
#                                                   531148905   regionprofile
#                                                   2175685273  regionprofile
# {'name': 'comp', 'type': 'function'}              5969722     regionprofile
#                                                   531148905   regionprofile
#                                                   2175685273  regionprofile
# {'name': 'comp_large', 'type': 'function'}        5969722     regionprofile
#                                                   531148905   regionprofile
#                                                   2175685273  regionprofile
# {'name': 'comp_small', 'type': 'function'}        5969722     regionprofile
#                                                   531148905   regionprofile
#                                                   2175685273  regionprofile
# {'name': 'correctness_check', 'type': 'function'} 5969722     regionprofile
#                                                   531148905   regionprofile
#                                                   2175685273  regionprofile
# {'name': 'data_init', 'type': 'function'}         5969722     regionprofile
#                                                   531148905   regionprofile
#                                                   2175685273  regionprofile
#
#                                                               Min time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              5969722          0.503831
#                                                   531148905        0.524052
#                                                   2175685273       2.006753
# {'name': 'comm', 'type': 'function'}              5969722          0.001271
#                                                   531148905        0.002760
#                                                   2175685273       0.015855
# {'name': 'MPI_Barrier', 'type': 'function'}       5969722          0.000926
#                                                   531148905        0.001239
#                                                   2175685273       0.008316
# {'name': 'comm_large', 'type': 'function'}        5969722          0.000237
#                                                   531148905        0.001328
#                                                   2175685273       0.005370
# {'name': 'MPI_Recv', 'type': 'function'}          5969722          0.000042
#                                                   531148905        0.000256
#                                                   2175685273       0.002225
# {'name': 'MPI_Scatter', 'type': 'function'}       5969722          0.000175
#                                                   531148905        0.001033
#                                                   2175685273       0.003229
# {'name': 'MPI_Send', 'type': 'function'}          5969722          0.000090
#                                                   531148905        0.000254
#                                                   2175685273       0.002110
# {'name': 'comm_small', 'type': 'function'}        5969722          0.000055
#                                                   531148905        0.000102
#                                                   2175685273       0.001728
# {'name': 'MPI_Bcast', 'type': 'function'}         5969722          0.000040
#                                                   531148905        0.000074
#                                                   2175685273       0.001715
# {'name': 'comp', 'type': 'function'}              5969722          0.005591
#                                                   531148905        0.026309
#                                                   2175685273       0.113340
# {'name': 'comp_large', 'type': 'function'}        5969722          0.005580
#                                                   531148905        0.026297
#                                                   2175685273       0.113326
# {'name': 'comp_small', 'type': 'function'}        5969722          0.000741
#                                                   531148905        0.002861
#                                                   2175685273       0.010768
# {'name': 'correctness_check', 'type': 'function'} 5969722          0.000178
#                                                   531148905        0.000683
#                                                   2175685273       0.002691
# {'name': 'data_init', 'type': 'function'}         5969722          0.000047
#                                                   531148905        0.000036
#                                                   2175685273       0.000039
#
#                                                               Max time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              5969722          0.505511
#                                                   531148905        0.528714
#                                                   2175685273       2.020479
# {'name': 'comm', 'type': 'function'}              5969722          0.006325
#                                                   531148905        0.013425
#                                                   2175685273       0.040928
# {'name': 'MPI_Barrier', 'type': 'function'}       5969722          0.005915
#                                                   531148905        0.011897
#                                                   2175685273       0.033061
# {'name': 'comm_large', 'type': 'function'}        5969722          0.000302
#                                                   531148905        0.001352
#                                                   2175685273       0.005767
# {'name': 'MPI_Recv', 'type': 'function'}          5969722          0.000042
#                                                   531148905        0.000256
#                                                   2175685273       0.002225
# {'name': 'MPI_Scatter', 'type': 'function'}       5969722          0.000190
#                                                   531148905        0.001074
#                                                   2175685273       0.003511
# {'name': 'MPI_Send', 'type': 'function'}          5969722          0.000090
#                                                   531148905        0.000254
#                                                   2175685273       0.002110
# {'name': 'comm_small', 'type': 'function'}        5969722          0.000056
#                                                   531148905        0.000126
#                                                   2175685273       0.002447
# {'name': 'MPI_Bcast', 'type': 'function'}         5969722          0.000043
#                                                   531148905        0.000111
#                                                   2175685273       0.002433
# {'name': 'comp', 'type': 'function'}              5969722          0.007252
#                                                   531148905        0.029223
#                                                   2175685273       0.124439
# {'name': 'comp_large', 'type': 'function'}        5969722          0.006491
#                                                   531148905        0.026331
#                                                   2175685273       0.113642
# {'name': 'comp_small', 'type': 'function'}        5969722          0.000741
#                                                   531148905        0.002861
#                                                   2175685273       0.010768
# {'name': 'correctness_check', 'type': 'function'} 5969722          0.000178
#                                                   531148905        0.000683
#                                                   2175685273       0.002691
# {'name': 'data_init', 'type': 'function'}         5969722          0.001779
#                                                   531148905        0.006678
#                                                   2175685273       0.024574
#
#                                                               Avg time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              5969722          0.504671
#                                                   531148905        0.526383
#                                                   2175685273       2.013616
# {'name': 'comm', 'type': 'function'}              5969722          0.003798
#                                                   531148905        0.008092
#                                                   2175685273       0.028392
# {'name': 'MPI_Barrier', 'type': 'function'}       5969722          0.003421
#                                                   531148905        0.006568
#                                                   2175685273       0.020689
# {'name': 'comm_large', 'type': 'function'}        5969722          0.000269
#                                                   531148905        0.001340
#                                                   2175685273       0.005569
# {'name': 'MPI_Recv', 'type': 'function'}          5969722          0.000042
#                                                   531148905        0.000256
#                                                   2175685273       0.002225
# {'name': 'MPI_Scatter', 'type': 'function'}       5969722          0.000183
#                                                   531148905        0.001054
#                                                   2175685273       0.003370
# {'name': 'MPI_Send', 'type': 'function'}          5969722          0.000090
#                                                   531148905        0.000254
#                                                   2175685273       0.002110
# {'name': 'comm_small', 'type': 'function'}        5969722          0.000055
#                                                   531148905        0.000114
#                                                   2175685273       0.002087
# {'name': 'MPI_Bcast', 'type': 'function'}         5969722          0.000042
#                                                   531148905        0.000093
#                                                   2175685273       0.002074
# {'name': 'comp', 'type': 'function'}              5969722          0.006422
#                                                   531148905        0.027766
#                                                   2175685273       0.118889
# {'name': 'comp_large', 'type': 'function'}        5969722          0.006035
#                                                   531148905        0.026314
#                                                   2175685273       0.113484
# {'name': 'comp_small', 'type': 'function'}        5969722          0.000741
#                                                   531148905        0.002861
#                                                   2175685273       0.010768
# {'name': 'correctness_check', 'type': 'function'} 5969722          0.000178
#                                                   531148905        0.000683
#                                                   2175685273       0.002691
# {'name': 'data_init', 'type': 'function'}         5969722          0.000913
#                                                   531148905        0.003357
#                                                   2175685273       0.012306
#
#                                                               Total time  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              5969722       1.009342
#                                                   531148905     1.052766
#                                                   2175685273    4.027231
# {'name': 'comm', 'type': 'function'}              5969722       0.007596
#                                                   531148905     0.016185
#                                                   2175685273    0.056783
# {'name': 'MPI_Barrier', 'type': 'function'}       5969722       0.006841
#                                                   531148905     0.013135
#                                                   2175685273    0.041377
# {'name': 'comm_large', 'type': 'function'}        5969722       0.000539
#                                                   531148905     0.002680
#                                                   2175685273    0.011137
# {'name': 'MPI_Recv', 'type': 'function'}          5969722       0.000042
#                                                   531148905     0.000256
#                                                   2175685273    0.002225
# {'name': 'MPI_Scatter', 'type': 'function'}       5969722       0.000365
#                                                   531148905     0.002107
#                                                   2175685273    0.006739
# {'name': 'MPI_Send', 'type': 'function'}          5969722       0.000090
#                                                   531148905     0.000254
#                                                   2175685273    0.002110
# {'name': 'comm_small', 'type': 'function'}        5969722       0.000111
#                                                   531148905     0.000228
#                                                   2175685273    0.004175
# {'name': 'MPI_Bcast', 'type': 'function'}         5969722       0.000083
#                                                   531148905     0.000185
#                                                   2175685273    0.004148
# {'name': 'comp', 'type': 'function'}              5969722       0.012843
#                                                   531148905     0.055532
#                                                   2175685273    0.237779
# {'name': 'comp_large', 'type': 'function'}        5969722       0.012070
#                                                   531148905     0.052628
#                                                   2175685273    0.226967
# {'name': 'comp_small', 'type': 'function'}        5969722       0.000741
#                                                   531148905     0.002861
#                                                   2175685273    0.010768
# {'name': 'correctness_check', 'type': 'function'} 5969722       0.000178
#                                                   531148905     0.000683
#                                                   2175685273    0.002691
# {'name': 'data_init', 'type': 'function'}         5969722       0.001827
#                                                   531148905     0.006714
#                                                   2175685273    0.024613
#
#                                                               Variance time/rank  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              5969722               0.000001
#                                                   531148905             0.000005
#                                                   2175685273            0.000047
# {'name': 'comm', 'type': 'function'}              5969722               0.000006
#                                                   531148905             0.000028
#                                                   2175685273            0.000157
# {'name': 'MPI_Barrier', 'type': 'function'}       5969722               0.000006
#                                                   531148905             0.000028
#                                                   2175685273            0.000153
# {'name': 'comm_large', 'type': 'function'}        5969722               0.000000
#                                                   531148905             0.000000
#                                                   2175685273            0.000000
# {'name': 'MPI_Recv', 'type': 'function'}          5969722               0.000000
#                                                   531148905             0.000000
#                                                   2175685273            0.000000
# {'name': 'MPI_Scatter', 'type': 'function'}       5969722               0.000000
#                                                   531148905             0.000000
#                                                   2175685273            0.000000
# {'name': 'MPI_Send', 'type': 'function'}          5969722               0.000000
#                                                   531148905             0.000000
#                                                   2175685273            0.000000
# {'name': 'comm_small', 'type': 'function'}        5969722               0.000000
#                                                   531148905             0.000000
#                                                   2175685273            0.000000
# {'name': 'MPI_Bcast', 'type': 'function'}         5969722               0.000000
#                                                   531148905             0.000000
#                                                   2175685273            0.000000
# {'name': 'comp', 'type': 'function'}              5969722               0.000001
#                                                   531148905             0.000002
#                                                   2175685273            0.000031
# {'name': 'comp_large', 'type': 'function'}        5969722               0.000000
#                                                   531148905             0.000000
#                                                   2175685273            0.000000
# {'name': 'comp_small', 'type': 'function'}        5969722               0.000000
#                                                   531148905             0.000000
#                                                   2175685273            0.000000
# {'name': 'correctness_check', 'type': 'function'} 5969722               0.000000
#                                                   531148905             0.000000
#                                                   2175685273            0.000000
# {'name': 'data_init', 'type': 'function'}         5969722               0.000001
#                                                   531148905             0.000011
#                                                   2175685273            0.000150
#
#                                                                            name
# node                                              profile
# {'name': 'main', 'type': 'function'}              5969722                  main
#                                                   531148905                main
#                                                   2175685273               main
# {'name': 'comm', 'type': 'function'}              5969722                  comm
#                                                   531148905                comm
#                                                   2175685273               comm
# {'name': 'MPI_Barrier', 'type': 'function'}       5969722           MPI_Barrier
#                                                   531148905         MPI_Barrier
#                                                   2175685273        MPI_Barrier
# {'name': 'comm_large', 'type': 'function'}        5969722            comm_large
#                                                   531148905          comm_large
#                                                   2175685273         comm_large
# {'name': 'MPI_Recv', 'type': 'function'}          5969722              MPI_Recv
#                                                   531148905            MPI_Recv
#                                                   2175685273           MPI_Recv
# {'name': 'MPI_Scatter', 'type': 'function'}       5969722           MPI_Scatter
#                                                   531148905         MPI_Scatter
#                                                   2175685273        MPI_Scatter
# {'name': 'MPI_Send', 'type': 'function'}          5969722              MPI_Send
#                                                   531148905            MPI_Send
#                                                   2175685273           MPI_Send
# {'name': 'comm_small', 'type': 'function'}        5969722            comm_small
#                                                   531148905          comm_small
#                                                   2175685273         comm_small
# {'name': 'MPI_Bcast', 'type': 'function'}         5969722             MPI_Bcast
#                                                   531148905           MPI_Bcast
#                                                   2175685273          MPI_Bcast
# {'name': 'comp', 'type': 'function'}              5969722                  comp
#                                                   531148905                comp
#                                                   2175685273               comp
# {'name': 'comp_large', 'type': 'function'}        5969722            comp_large
#                                                   531148905          comp_large
#                                                   2175685273         comp_large
# {'name': 'comp_small', 'type': 'function'}        5969722            comp_small
#                                                   531148905          comp_small
#                                                   2175685273         comp_small
# {'name': 'correctness_check', 'type': 'function'} 5969722     correctness_check
#                                                   531148905   correctness_check
#                                                   2175685273  correctness_check
# {'name': 'data_init', 'type': 'function'}         5969722             data_init
#                                                   531148905           data_init
#                                                   2175685273          data_init

# %%
tk.metadata
# Out:
#            cali.caliper.version  mpi.world.size  \
# profile
# 5969722              2.11.0-dev               2
# 531148905            2.11.0-dev               2
# 2175685273           2.11.0-dev               2
#
#                                                  spot.metrics  \
# profile
# 5969722     min#inclusive#sum#time.duration,max#inclusive#...
# 531148905   min#inclusive#sum#time.duration,max#inclusive#...
# 2175685273  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 5969722                                               2
# 531148905                                             2
# 2175685273                                            2
#
#                         spot.options  spot.channels cali.channel  \
# profile
# 5969722     time.variance,node.order  regionprofile         spot
# 531148905   time.variance,node.order  regionprofile         spot
# 2175685273  time.variance,node.order  regionprofile         spot
#
#            spot:node.order          spot:output spot:time.variance  \
# profile
# 5969722               true    p2-a65536-o0.cali               true
# 531148905             true   p2-a262144-o0.cali               true
# 2175685273            true  p2-a1048576-o0.cali               true
#
#             launchdate                                          libraries  \
# profile
# 5969722     1700078938  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 531148905   1700081456  [/scratch/group/csce435-f23/Caliper/caliper/li...
# 2175685273  1700086428  [/scratch/group/csce435-f23/Caliper/caliper/li...
#
#                                   cmdline cluster  Algorithm ProgrammingModel  \
# profile
# 5969722       [./quicksort_mpi, 65536, 0]       c  QuickSort              MPI
# 531148905    [./quicksort_mpi, 262144, 0]       c  QuickSort              MPI
# 2175685273  [./quicksort_mpi, 1048576, 0]       c  QuickSort              MPI
#
#             SizeOfDatatype  InputSize InputType  num_procs  group_num  \
# profile
# 5969722                  4      65536    Random          2         23
# 531148905                4     262144    Random          2         23
# 2175685273               4    1048576    Random          2         23
#
#            implementation_source
# profile
# 5969722                   Online
# 531148905                 Online
# 2175685273                Online

# %%
gb = tk.groupby("InputType")
# Out:
# 1  thickets created...
# {'Random': <thicket.thicket.Thicket object at 0x000001751EFE00D0>}

# %%
print(gb.keys())
# Out:
# dict_keys([65536, 262144, 1048576])

# %%
ctk = th.Thicket.concat_thickets(
  thickets=list(gb.values()),
  headers=list(gb.keys()),
  axis="columns",
  metadata_key="InputSize"
)

# %%
ctk.dataframe
# Out:
#                                                             Random  \
#                                                                nid
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              65536          1
#                                                   262144         1
#                                                   1048576        1
# {'name': 'comm', 'type': 'function'}              65536          3
#                                                   262144         3
#                                                   1048576        3
# {'name': 'MPI_Barrier', 'type': 'function'}       65536          4
#                                                   262144         4
#                                                   1048576        4
# {'name': 'comm_large', 'type': 'function'}        65536          7
#                                                   262144         7
#                                                   1048576        7
# {'name': 'MPI_Recv', 'type': 'function'}          65536         11
#                                                   262144        11
#                                                   1048576       11
# {'name': 'MPI_Scatter', 'type': 'function'}       65536          8
#                                                   262144         8
#                                                   1048576        8
# {'name': 'MPI_Send', 'type': 'function'}          65536         14
#                                                   262144        14
#                                                   1048576       14
# {'name': 'comm_small', 'type': 'function'}        65536          5
#                                                   262144         5
#                                                   1048576        5
# {'name': 'MPI_Bcast', 'type': 'function'}         65536          6
#                                                   262144         6
#                                                   1048576        6
# {'name': 'comp', 'type': 'function'}              65536          9
#                                                   262144         9
#                                                   1048576        9
# {'name': 'comp_large', 'type': 'function'}        65536         10
#                                                   262144        10
#                                                   1048576       10
# {'name': 'comp_small', 'type': 'function'}        65536         12
#                                                   262144        12
#                                                   1048576       12
# {'name': 'correctness_check', 'type': 'function'} 65536         13
#                                                   262144        13
#                                                   1048576       13
# {'name': 'data_init', 'type': 'function'}         65536          2
#                                                   262144         2
#                                                   1048576        2
#
#                                                                             \
#                                                               spot.channel
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              65536      regionprofile
#                                                   262144     regionprofile
#                                                   1048576    regionprofile
# {'name': 'comm', 'type': 'function'}              65536      regionprofile
#                                                   262144     regionprofile
#                                                   1048576    regionprofile
# {'name': 'MPI_Barrier', 'type': 'function'}       65536      regionprofile
#                                                   262144     regionprofile
#                                                   1048576    regionprofile
# {'name': 'comm_large', 'type': 'function'}        65536      regionprofile
#                                                   262144     regionprofile
#                                                   1048576    regionprofile
# {'name': 'MPI_Recv', 'type': 'function'}          65536      regionprofile
#                                                   262144     regionprofile
#                                                   1048576    regionprofile
# {'name': 'MPI_Scatter', 'type': 'function'}       65536      regionprofile
#                                                   262144     regionprofile
#                                                   1048576    regionprofile
# {'name': 'MPI_Send', 'type': 'function'}          65536      regionprofile
#                                                   262144     regionprofile
#                                                   1048576    regionprofile
# {'name': 'comm_small', 'type': 'function'}        65536      regionprofile
#                                                   262144     regionprofile
#                                                   1048576    regionprofile
# {'name': 'MPI_Bcast', 'type': 'function'}         65536      regionprofile
#                                                   262144     regionprofile
#                                                   1048576    regionprofile
# {'name': 'comp', 'type': 'function'}              65536      regionprofile
#                                                   262144     regionprofile
#                                                   1048576    regionprofile
# {'name': 'comp_large', 'type': 'function'}        65536      regionprofile
#                                                   262144     regionprofile
#                                                   1048576    regionprofile
# {'name': 'comp_small', 'type': 'function'}        65536      regionprofile
#                                                   262144     regionprofile
#                                                   1048576    regionprofile
# {'name': 'correctness_check', 'type': 'function'} 65536      regionprofile
#                                                   262144     regionprofile
#                                                   1048576    regionprofile
# {'name': 'data_init', 'type': 'function'}         65536      regionprofile
#                                                   262144     regionprofile
#                                                   1048576    regionprofile
#
#                                                                            \
#                                                             Min time/rank
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              65536          0.503831
#                                                   262144         0.524052
#                                                   1048576        2.006753
# {'name': 'comm', 'type': 'function'}              65536          0.001271
#                                                   262144         0.002760
#                                                   1048576        0.015855
# {'name': 'MPI_Barrier', 'type': 'function'}       65536          0.000926
#                                                   262144         0.001239
#                                                   1048576        0.008316
# {'name': 'comm_large', 'type': 'function'}        65536          0.000237
#                                                   262144         0.001328
#                                                   1048576        0.005370
# {'name': 'MPI_Recv', 'type': 'function'}          65536          0.000042
#                                                   262144         0.000256
#                                                   1048576        0.002225
# {'name': 'MPI_Scatter', 'type': 'function'}       65536          0.000175
#                                                   262144         0.001033
#                                                   1048576        0.003229
# {'name': 'MPI_Send', 'type': 'function'}          65536          0.000090
#                                                   262144         0.000254
#                                                   1048576        0.002110
# {'name': 'comm_small', 'type': 'function'}        65536          0.000055
#                                                   262144         0.000102
#                                                   1048576        0.001728
# {'name': 'MPI_Bcast', 'type': 'function'}         65536          0.000040
#                                                   262144         0.000074
#                                                   1048576        0.001715
# {'name': 'comp', 'type': 'function'}              65536          0.005591
#                                                   262144         0.026309
#                                                   1048576        0.113340
# {'name': 'comp_large', 'type': 'function'}        65536          0.005580
#                                                   262144         0.026297
#                                                   1048576        0.113326
# {'name': 'comp_small', 'type': 'function'}        65536          0.000741
#                                                   262144         0.002861
#                                                   1048576        0.010768
# {'name': 'correctness_check', 'type': 'function'} 65536          0.000178
#                                                   262144         0.000683
#                                                   1048576        0.002691
# {'name': 'data_init', 'type': 'function'}         65536          0.000047
#                                                   262144         0.000036
#                                                   1048576        0.000039
#
#                                                                            \
#                                                             Max time/rank
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              65536          0.505511
#                                                   262144         0.528714
#                                                   1048576        2.020479
# {'name': 'comm', 'type': 'function'}              65536          0.006325
#                                                   262144         0.013425
#                                                   1048576        0.040928
# {'name': 'MPI_Barrier', 'type': 'function'}       65536          0.005915
#                                                   262144         0.011897
#                                                   1048576        0.033061
# {'name': 'comm_large', 'type': 'function'}        65536          0.000302
#                                                   262144         0.001352
#                                                   1048576        0.005767
# {'name': 'MPI_Recv', 'type': 'function'}          65536          0.000042
#                                                   262144         0.000256
#                                                   1048576        0.002225
# {'name': 'MPI_Scatter', 'type': 'function'}       65536          0.000190
#                                                   262144         0.001074
#                                                   1048576        0.003511
# {'name': 'MPI_Send', 'type': 'function'}          65536          0.000090
#                                                   262144         0.000254
#                                                   1048576        0.002110
# {'name': 'comm_small', 'type': 'function'}        65536          0.000056
#                                                   262144         0.000126
#                                                   1048576        0.002447
# {'name': 'MPI_Bcast', 'type': 'function'}         65536          0.000043
#                                                   262144         0.000111
#                                                   1048576        0.002433
# {'name': 'comp', 'type': 'function'}              65536          0.007252
#                                                   262144         0.029223
#                                                   1048576        0.124439
# {'name': 'comp_large', 'type': 'function'}        65536          0.006491
#                                                   262144         0.026331
#                                                   1048576        0.113642
# {'name': 'comp_small', 'type': 'function'}        65536          0.000741
#                                                   262144         0.002861
#                                                   1048576        0.010768
# {'name': 'correctness_check', 'type': 'function'} 65536          0.000178
#                                                   262144         0.000683
#                                                   1048576        0.002691
# {'name': 'data_init', 'type': 'function'}         65536          0.001779
#                                                   262144         0.006678
#                                                   1048576        0.024574
#
#                                                                            \
#                                                             Avg time/rank
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              65536          0.504671
#                                                   262144         0.526383
#                                                   1048576        2.013616
# {'name': 'comm', 'type': 'function'}              65536          0.003798
#                                                   262144         0.008092
#                                                   1048576        0.028392
# {'name': 'MPI_Barrier', 'type': 'function'}       65536          0.003421
#                                                   262144         0.006568
#                                                   1048576        0.020689
# {'name': 'comm_large', 'type': 'function'}        65536          0.000269
#                                                   262144         0.001340
#                                                   1048576        0.005569
# {'name': 'MPI_Recv', 'type': 'function'}          65536          0.000042
#                                                   262144         0.000256
#                                                   1048576        0.002225
# {'name': 'MPI_Scatter', 'type': 'function'}       65536          0.000183
#                                                   262144         0.001054
#                                                   1048576        0.003370
# {'name': 'MPI_Send', 'type': 'function'}          65536          0.000090
#                                                   262144         0.000254
#                                                   1048576        0.002110
# {'name': 'comm_small', 'type': 'function'}        65536          0.000055
#                                                   262144         0.000114
#                                                   1048576        0.002087
# {'name': 'MPI_Bcast', 'type': 'function'}         65536          0.000042
#                                                   262144         0.000093
#                                                   1048576        0.002074
# {'name': 'comp', 'type': 'function'}              65536          0.006422
#                                                   262144         0.027766
#                                                   1048576        0.118889
# {'name': 'comp_large', 'type': 'function'}        65536          0.006035
#                                                   262144         0.026314
#                                                   1048576        0.113484
# {'name': 'comp_small', 'type': 'function'}        65536          0.000741
#                                                   262144         0.002861
#                                                   1048576        0.010768
# {'name': 'correctness_check', 'type': 'function'} 65536          0.000178
#                                                   262144         0.000683
#                                                   1048576        0.002691
# {'name': 'data_init', 'type': 'function'}         65536          0.000913
#                                                   262144         0.003357
#                                                   1048576        0.012306
#
#                                                                         \
#                                                             Total time
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              65536       1.009342
#                                                   262144      1.052766
#                                                   1048576     4.027231
# {'name': 'comm', 'type': 'function'}              65536       0.007596
#                                                   262144      0.016185
#                                                   1048576     0.056783
# {'name': 'MPI_Barrier', 'type': 'function'}       65536       0.006841
#                                                   262144      0.013135
#                                                   1048576     0.041377
# {'name': 'comm_large', 'type': 'function'}        65536       0.000539
#                                                   262144      0.002680
#                                                   1048576     0.011137
# {'name': 'MPI_Recv', 'type': 'function'}          65536       0.000042
#                                                   262144      0.000256
#                                                   1048576     0.002225
# {'name': 'MPI_Scatter', 'type': 'function'}       65536       0.000365
#                                                   262144      0.002107
#                                                   1048576     0.006739
# {'name': 'MPI_Send', 'type': 'function'}          65536       0.000090
#                                                   262144      0.000254
#                                                   1048576     0.002110
# {'name': 'comm_small', 'type': 'function'}        65536       0.000111
#                                                   262144      0.000228
#                                                   1048576     0.004175
# {'name': 'MPI_Bcast', 'type': 'function'}         65536       0.000083
#                                                   262144      0.000185
#                                                   1048576     0.004148
# {'name': 'comp', 'type': 'function'}              65536       0.012843
#                                                   262144      0.055532
#                                                   1048576     0.237779
# {'name': 'comp_large', 'type': 'function'}        65536       0.012070
#                                                   262144      0.052628
#                                                   1048576     0.226967
# {'name': 'comp_small', 'type': 'function'}        65536       0.000741
#                                                   262144      0.002861
#                                                   1048576     0.010768
# {'name': 'correctness_check', 'type': 'function'} 65536       0.000178
#                                                   262144      0.000683
#                                                   1048576     0.002691
# {'name': 'data_init', 'type': 'function'}         65536       0.001827
#                                                   262144      0.006714
#                                                   1048576     0.024613
#
#                                                                                 \
#                                                             Variance time/rank
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              65536               0.000001
#                                                   262144              0.000005
#                                                   1048576             0.000047
# {'name': 'comm', 'type': 'function'}              65536               0.000006
#                                                   262144              0.000028
#                                                   1048576             0.000157
# {'name': 'MPI_Barrier', 'type': 'function'}       65536               0.000006
#                                                   262144              0.000028
#                                                   1048576             0.000153
# {'name': 'comm_large', 'type': 'function'}        65536               0.000000
#                                                   262144              0.000000
#                                                   1048576             0.000000
# {'name': 'MPI_Recv', 'type': 'function'}          65536               0.000000
#                                                   262144              0.000000
#                                                   1048576             0.000000
# {'name': 'MPI_Scatter', 'type': 'function'}       65536               0.000000
#                                                   262144              0.000000
#                                                   1048576             0.000000
# {'name': 'MPI_Send', 'type': 'function'}          65536               0.000000
#                                                   262144              0.000000
#                                                   1048576             0.000000
# {'name': 'comm_small', 'type': 'function'}        65536               0.000000
#                                                   262144              0.000000
#                                                   1048576             0.000000
# {'name': 'MPI_Bcast', 'type': 'function'}         65536               0.000000
#                                                   262144              0.000000
#                                                   1048576             0.000000
# {'name': 'comp', 'type': 'function'}              65536               0.000001
#                                                   262144              0.000002
#                                                   1048576             0.000031
# {'name': 'comp_large', 'type': 'function'}        65536               0.000000
#                                                   262144              0.000000
#                                                   1048576             0.000000
# {'name': 'comp_small', 'type': 'function'}        65536               0.000000
#                                                   262144              0.000000
#                                                   1048576             0.000000
# {'name': 'correctness_check', 'type': 'function'} 65536               0.000000
#                                                   262144              0.000000
#                                                   1048576             0.000000
# {'name': 'data_init', 'type': 'function'}         65536               0.000001
#                                                   262144              0.000011
#                                                   1048576             0.000150
#
#                                                                           name
#
# node                                              InputSize
# {'name': 'main', 'type': 'function'}              65536                   main
#                                                   262144                  main
#                                                   1048576                 main
# {'name': 'comm', 'type': 'function'}              65536                   comm
#                                                   262144                  comm
#                                                   1048576                 comm
# {'name': 'MPI_Barrier', 'type': 'function'}       65536            MPI_Barrier
#                                                   262144           MPI_Barrier
#                                                   1048576          MPI_Barrier
# {'name': 'comm_large', 'type': 'function'}        65536             comm_large
#                                                   262144            comm_large
#                                                   1048576           comm_large
# {'name': 'MPI_Recv', 'type': 'function'}          65536               MPI_Recv
#                                                   262144              MPI_Recv
#                                                   1048576             MPI_Recv
# {'name': 'MPI_Scatter', 'type': 'function'}       65536            MPI_Scatter
#                                                   262144           MPI_Scatter
#                                                   1048576          MPI_Scatter
# {'name': 'MPI_Send', 'type': 'function'}          65536               MPI_Send
#                                                   262144              MPI_Send
#                                                   1048576             MPI_Send
# {'name': 'comm_small', 'type': 'function'}        65536             comm_small
#                                                   262144            comm_small
#                                                   1048576           comm_small
# {'name': 'MPI_Bcast', 'type': 'function'}         65536              MPI_Bcast
#                                                   262144             MPI_Bcast
#                                                   1048576            MPI_Bcast
# {'name': 'comp', 'type': 'function'}              65536                   comp
#                                                   262144                  comp
#                                                   1048576                 comp
# {'name': 'comp_large', 'type': 'function'}        65536             comp_large
#                                                   262144            comp_large
#                                                   1048576           comp_large
# {'name': 'comp_small', 'type': 'function'}        65536             comp_small
#                                                   262144            comp_small
#                                                   1048576           comp_small
# {'name': 'correctness_check', 'type': 'function'} 65536      correctness_check
#                                                   262144     correctness_check
#                                                   1048576    correctness_check
# {'name': 'data_init', 'type': 'function'}         65536              data_init
#                                                   262144             data_init
#                                                   1048576            data_init

# %%
dropTheseCol = ["nid", "spot.channel",  "Min time/rank", "Max time/rank", "Avg time/rank", "Variance time/rank"]
# sizes = [65536, 262144, 1048576]
sizes = ["Random"]
dropArr = [("node", "")]

for c in dropTheseCol:
    for s in sizes:
        dropArr.append((s, c))
    

ctk.dataframe = ctk.dataframe.reset_index().drop(dropArr, axis=1)

ctk.dataframe = ctk.dataframe.rename({("name", ""): "name", ("InputSize", ""): "InputSize"}).set_index(["name", "InputSize"])


ctk.dataframe
# Out:
#                                 Random
#                             Total time
# name              InputSize
# main              65536       1.009342
#                   262144      1.052766
#                   1048576     4.027231
# comm              65536       0.007596
#                   262144      0.016185
#                   1048576     0.056783
# MPI_Barrier       65536       0.006841
#                   262144      0.013135
#                   1048576     0.041377
# comm_large        65536       0.000539
#                   262144      0.002680
#                   1048576     0.011137
# MPI_Recv          65536       0.000042
#                   262144      0.000256
#                   1048576     0.002225
# MPI_Scatter       65536       0.000365
#                   262144      0.002107
#                   1048576     0.006739
# MPI_Send          65536       0.000090
#                   262144      0.000254
#                   1048576     0.002110
# comm_small        65536       0.000111
#                   262144      0.000228
#                   1048576     0.004175
# MPI_Bcast         65536       0.000083
#                   262144      0.000185
#                   1048576     0.004148
# comp              65536       0.012843
#                   262144      0.055532
#                   1048576     0.237779
# comp_large        65536       0.012070
#                   262144      0.052628
#                   1048576     0.226967
# comp_small        65536       0.000741
#                   262144      0.002861
#                   1048576     0.010768
# correctness_check 65536       0.000178
#                   262144      0.000683
#                   1048576     0.002691
# data_init         65536       0.001827
#                   262144      0.006714
#                   1048576     0.024613

# %%
function_names = set(ctk.dataframe.index.get_level_values("name"))
# world_size = sorted(list(set(ctk.dataframe.index.get_level_values("mpi.world.size"))))
num_values = sorted(ctk.dataframe.columns.tolist())

print(function_names)
# Out:
# {'main', 'MPI_Scatter', 'MPI_Send', 'MPI_Barrier', 'MPI_Bcast', 'comp_small', 'comm_large', 'comm', 'comp', 'correctness_check', 'data_init', 'MPI_Recv', 'comp_large', 'comm_small'}

# %%
def plot_pandas(df, title, xlabel, ylabel, loglog):
    plot = df.plot(kind="line",
                  marker='o',
                  title=title,
                  xlabel=xlabel,
                  ylabel=ylabel,
                  grid=True,
                  loglog=loglog
                )
    return plot

# %%
ctk.dataframe.loc['main']
# Out:
#               Random
#           Total time
# InputSize
# 65536       1.009342
# 262144      1.052766
# 1048576     4.027231

# %%
for name in function_names:
    plot_pandas(
        df=ctk.dataframe.loc[name],
        title=f"{algorithm} {implementation} {sorted_type} input: {name}",
        xlabel="Input Size",
        ylabel="Time (seconds)",
        loglog=True
    )
