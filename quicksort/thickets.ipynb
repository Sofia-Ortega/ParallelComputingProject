# %%
# %pip install llnl-thicket
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import thicket as th
import matplotlib.pyplot as plt
from glob import glob

# Load the CALI data
tk = th.Thicket.from_caliperreader(glob("mpi/cali/plotted_calis/*.cali"))

# Plot the data
tk.dataframe
# Out:
#                                                               nid  \
# node                                              profile
# {'name': 'main', 'type': 'function'}              120668737     1
#                                                   445538371     1
#                                                   2389089045    1
#                                                   2435505357    1
# {'name': 'comm', 'type': 'function'}              120668737     3
#                                                   445538371     3
#                                                   2389089045    3
#                                                   2435505357    3
# {'name': 'MPI_Barrier', 'type': 'function'}       120668737     4
#                                                   445538371     4
#                                                   2389089045    4
#                                                   2435505357    4
# ...

# %%
tk.metadata
# Out:
#            cali.caliper.version  mpi.world.size  \
# profile
# 120668737            2.11.0-dev              64
# 445538371            2.11.0-dev              64
# 2389089045           2.11.0-dev              64
# 2435505357           2.11.0-dev              64
#
#                                                  spot.metrics  \
# profile
# 120668737   min#inclusive#sum#time.duration,max#inclusive#...
# 445538371   min#inclusive#sum#time.duration,max#inclusive#...
# 2389089045  min#inclusive#sum#time.duration,max#inclusive#...
# 2435505357  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version  \
# profile
# 120668737                                             2
# 445538371                                             2
# 2389089045                                            2
# 2435505357                                            2
#
#                         spot.options  spot.channels cali.channel  \
# profile
# ...

# %%
tkNewDF = tk.groupby("InputSize")

tkNewDF2 = th.Thicket.concat_thickets(
    thickets=list(tkNewDF.values()),
    headers=list(tkNewDF.keys()),
    axis="columns",
    metadata_key="spot:output"
)

# Delete the old InputSize column and replace it with a new one that is ["Reverse Sorted, Sorted, Random, 1% Perturbed"]
# tkNewDF2.dataframe.drop(columns=["InputType"], inplace=True)
# tkNewDF2.dataframe["InputType"] = ["Reverse Sorted", "Sorted", "Random", "1% Perturbed"]

tkNewDF2.dataframe
# Out:
# 1  thickets created...
# {262144: <thicket.thicket.Thicket object at 0x28fa60410>}
#                                                                       262144  \
#                                                                          nid
# node                                              spot:output
# {'name': 'main', 'type': 'function'}              p64-a262144-o0.cali      1
#                                                   p64-a262144-o1.cali      1
#                                                   p64-a262144-o2.cali      1
#                                                   p64-a262144-o3.cali      1
# {'name': 'comm', 'type': 'function'}              p64-a262144-o0.cali      3
#                                                   p64-a262144-o1.cali      3
#                                                   p64-a262144-o2.cali      3
#                                                   p64-a262144-o3.cali      3
# ...

# %%
# given the dataframe, we want to create the following dataframes:
#  - one for each input type, with each name being the index of the dataframe
# each row should contain, the name, the average time, and the input type (spot:output)
for i in tkNewDF2.dataframe["name"].keys:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/sriabhivenkat/Desktop/CSCE435/ParallelComputingProject/quicksort/thickets.ipynb Cell 5 line 4
#       <a href='vscode-notebook-cell:/Users/sriabhivenkat/Desktop/CSCE435/ParallelComputingProject/quicksort/thickets.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> # given the dataframe, we want to create the following dataframes:
#       <a href='vscode-notebook-cell:/Users/sriabhivenkat/Desktop/CSCE435/ParallelComputingProject/quicksort/thickets.ipynb#W5sZmlsZQ%3D%3D?line=1'>2</a> #  - one for each input type, with each name being the index of the dataframe
#       <a href='vscode-notebook-cell:/Users/sriabhivenkat/Desktop/CSCE435/ParallelComputingProject/quicksort/thickets.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> # each row should contain, the name, the average time, and the input type (spot:output)
# ...
