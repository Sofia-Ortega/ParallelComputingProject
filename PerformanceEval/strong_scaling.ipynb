# %%
import sys
from glob import glob

import matplotlib.pyplot as plt
import pandas as pd

import thicket as th

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

# %%
file_path = "./dataFiles/CUDA/Radix/random/*.cali"
algorithm = "Bitonic"
input_type = "Random"

# %%
all_files = glob(file_path)
print("Length:", len(all_files))

# problem_files = [1, 2, 6]
problem_files = []
files = []

for i in range(len(all_files)):
  if i not in problem_files:
    files.append(all_files[i])

print(files)

print("Problem Files:")
for p in problem_files:
  print(all_files[p])



tk = th.Thicket.from_caliperreader(files)
# Out:
# Length: 35
# ['./dataFiles/CUDA/Bitonic/random\\t1024-v1048576-option0.cali', './dataFiles/CUDA/Bitonic/random\\t1024-v16777216-option0.cali', './dataFiles/CUDA/Bitonic/random\\t1024-v262144-option0.cali', './dataFiles/CUDA/Bitonic/random\\t1024-v268435456-option0.cali', './dataFiles/CUDA/Bitonic/random\\t1024-v4194304-option0.cali', './dataFiles/CUDA/Bitonic/random\\t1024-v65536-option0.cali', './dataFiles/CUDA/Bitonic/random\\t1024-v67108864-option0.cali', './dataFiles/CUDA/Bitonic/random\\t128-v1048576-option0.cali', './dataFiles/CUDA/Bitonic/random\\t128-v16777216-option0.cali', './dataFiles/CUDA/Bitonic/random\\t128-v262144-option0.cali', './dataFiles/CUDA/Bitonic/random\\t128-v268435456-option0.cali', './dataFiles/CUDA/Bitonic/random\\t128-v4194304-option0.cali', './dataFiles/CUDA/Bitonic/random\\t128-v65536-option0.cali', './dataFiles/CUDA/Bitonic/random\\t128-v67108864-option0.cali', './dataFiles/CUDA/Bitonic/random\\t256-v1048576-option0.cali', './dataFiles/CUDA/Bitonic/random\\t256-v16777216-option0.cali', './dataFiles/CUDA/Bitonic/random\\t256-v262144-option0.cali', './dataFiles/CUDA/Bitonic/random\\t256-v268435456-option0.cali', './dataFiles/CUDA/Bitonic/random\\t256-v4194304-option0.cali', './dataFiles/CUDA/Bitonic/random\\t256-v65536-option0.cali', './dataFiles/CUDA/Bitonic/random\\t256-v67108864-option0.cali', './dataFiles/CUDA/Bitonic/random\\t512-v1048576-option0.cali', './dataFiles/CUDA/Bitonic/random\\t512-v16777216-option0.cali', './dataFiles/CUDA/Bitonic/random\\t512-v262144-option0.cali', './dataFiles/CUDA/Bitonic/random\\t512-v268435456-option0.cali', './dataFiles/CUDA/Bitonic/random\\t512-v4194304-option0.cali', './dataFiles/CUDA/Bitonic/random\\t512-v65536-option0.cali', './dataFiles/CUDA/Bitonic/random\\t512-v67108864-option0.cali', './dataFiles/CUDA/Bitonic/random\\t64-v1048576-option0.cali', './dataFiles/CUDA/Bitonic/random\\t64-v16777216-option0.cali', './dataFiles/CUDA/Bitonic/random\\t64-v262144-option0.cali', './dataFiles/CUDA/Bitonic/random\\t64-v268435456-option0.cali', './dataFiles/CUDA/Bitonic/random\\t64-v4194304-option0.cali', './dataFiles/CUDA/Bitonic/random\\t64-v65536-option0.cali', './dataFiles/CUDA/Bitonic/random\\t64-v67108864-option0.cali']
# Problem Files:

# %%
tk.metadata
# Out:
#            cali.caliper.version  \
# profile
# 28911768                 2.10.0
# 138873847                2.10.0
# 145809895                2.10.0
# 398479964                2.10.0
# 414139192                2.10.0
# 566945301                2.10.0
# 725055708                2.10.0
# 866223830                2.10.0
# 987686564                2.10.0
# 1228480942               2.10.0
# 1334542814               2.10.0
# 1411880569               2.10.0
# 1544777819               2.10.0
# 1555372682               2.10.0
# 1717221219               2.10.0
# 1795197380               2.10.0
# 2172883580               2.10.0
# 2349877696               2.10.0
# 2359956581               2.10.0
# 2519980046               2.10.0
# 2579055440               2.10.0
# 2730693273               2.10.0
# 2863096306               2.10.0
# 2889946342               2.10.0
# 2952006503               2.10.0
# 2981673489               2.10.0
# 3075663633               2.10.0
# 3106592697               2.10.0
# 3113764014               2.10.0
# 3349665014               2.10.0
# 3393644004               2.10.0
# 3628762412               2.10.0
# 3661199063               2.10.0
# 3718772862               2.10.0
# 4153930878               2.10.0
#
#                                                  spot.metrics  \
# profile
# 28911768    min#inclusive#sum#time.duration,max#inclusive#...
# 138873847   min#inclusive#sum#time.duration,max#inclusive#...
# 145809895   min#inclusive#sum#time.duration,max#inclusive#...
# 398479964   min#inclusive#sum#time.duration,max#inclusive#...
# 414139192   min#inclusive#sum#time.duration,max#inclusive#...
# 566945301   min#inclusive#sum#time.duration,max#inclusive#...
# 725055708   min#inclusive#sum#time.duration,max#inclusive#...
# 866223830   min#inclusive#sum#time.duration,max#inclusive#...
# 987686564   min#inclusive#sum#time.duration,max#inclusive#...
# 1228480942  min#inclusive#sum#time.duration,max#inclusive#...
# 1334542814  min#inclusive#sum#time.duration,max#inclusive#...
# 1411880569  min#inclusive#sum#time.duration,max#inclusive#...
# 1544777819  min#inclusive#sum#time.duration,max#inclusive#...
# 1555372682  min#inclusive#sum#time.duration,max#inclusive#...
# 1717221219  min#inclusive#sum#time.duration,max#inclusive#...
# 1795197380  min#inclusive#sum#time.duration,max#inclusive#...
# 2172883580  min#inclusive#sum#time.duration,max#inclusive#...
# 2349877696  min#inclusive#sum#time.duration,max#inclusive#...
# 2359956581  min#inclusive#sum#time.duration,max#inclusive#...
# 2519980046  min#inclusive#sum#time.duration,max#inclusive#...
# 2579055440  min#inclusive#sum#time.duration,max#inclusive#...
# 2730693273  min#inclusive#sum#time.duration,max#inclusive#...
# 2863096306  min#inclusive#sum#time.duration,max#inclusive#...
# 2889946342  min#inclusive#sum#time.duration,max#inclusive#...
# 2952006503  min#inclusive#sum#time.duration,max#inclusive#...
# 2981673489  min#inclusive#sum#time.duration,max#inclusive#...
# 3075663633  min#inclusive#sum#time.duration,max#inclusive#...
# 3106592697  min#inclusive#sum#time.duration,max#inclusive#...
# 3113764014  min#inclusive#sum#time.duration,max#inclusive#...
# 3349665014  min#inclusive#sum#time.duration,max#inclusive#...
# 3393644004  min#inclusive#sum#time.duration,max#inclusive#...
# 3628762412  min#inclusive#sum#time.duration,max#inclusive#...
# 3661199063  min#inclusive#sum#time.duration,max#inclusive#...
# 3718772862  min#inclusive#sum#time.duration,max#inclusive#...
# 4153930878  min#inclusive#sum#time.duration,max#inclusive#...
#
#            spot.timeseries.metrics  spot.format.version spot.options  \
# profile
# 28911768                                              2   node.order
# 138873847                                             2   node.order
# 145809895                                             2   node.order
# 398479964                                             2   node.order
# 414139192                                             2   node.order
# 566945301                                             2   node.order
# 725055708                                             2   node.order
# 866223830                                             2   node.order
# 987686564                                             2   node.order
# 1228480942                                            2   node.order
# 1334542814                                            2   node.order
# 1411880569                                            2   node.order
# 1544777819                                            2   node.order
# 1555372682                                            2   node.order
# 1717221219                                            2   node.order
# 1795197380                                            2   node.order
# 2172883580                                            2   node.order
# 2349877696                                            2   node.order
# 2359956581                                            2   node.order
# 2519980046                                            2   node.order
# 2579055440                                            2   node.order
# 2730693273                                            2   node.order
# 2863096306                                            2   node.order
# 2889946342                                            2   node.order
# 2952006503                                            2   node.order
# 2981673489                                            2   node.order
# 3075663633                                            2   node.order
# 3106592697                                            2   node.order
# 3113764014                                            2   node.order
# 3349665014                                            2   node.order
# 3393644004                                            2   node.order
# 3628762412                                            2   node.order
# 3661199063                                            2   node.order
# 3718772862                                            2   node.order
# 4153930878                                            2   node.order
#
#             spot.channels cali.channel  launchdate  \
# profile
# 28911768    regionprofile         spot  1701938196
# 138873847   regionprofile         spot  1701938164
# 145809895   regionprofile         spot  1701938164
# 398479964   regionprofile         spot  1701938152
# 414139192   regionprofile         spot  1701938152
# 566945301   regionprofile         spot  1701938173
# 725055708   regionprofile         spot  1701938196
# 866223830   regionprofile         spot  1701938196
# 987686564   regionprofile         spot  1701938151
# 1228480942  regionprofile         spot  1701938164
# 1334542814  regionprofile         spot  1701938135
# 1411880569  regionprofile         spot  1701938152
# 1544777819  regionprofile         spot  1701938152
# 1555372682  regionprofile         spot  1701938173
# 1717221219  regionprofile         spot  1701938164
# 1795197380  regionprofile         spot  1701938215
# 2172883580  regionprofile         spot  1701938173
# 2349877696  regionprofile         spot  1701938173
# 2359956581  regionprofile         spot  1701938196
# 2519980046  regionprofile         spot  1701938195
# 2579055440  regionprofile         spot  1701938198
# 2730693273  regionprofile         spot  1701938173
# 2863096306  regionprofile         spot  1701938164
# 2889946342  regionprofile         spot  1701938173
# 2952006503  regionprofile         spot  1701938215
# 2981673489  regionprofile         spot  1701938195
# 3075663633  regionprofile         spot  1701938152
# 3106592697  regionprofile         spot  1701938196
# 3113764014  regionprofile         spot  1701938133
# 3349665014  regionprofile         spot  1701938152
# 3393644004  regionprofile         spot  1701938152
# 3628762412  regionprofile         spot  1701938198
# 3661199063  regionprofile         spot  1701938152
# 3718772862  regionprofile         spot  1701938164
# 4153930878  regionprofile         spot  1701938198
#
#                                                     libraries  \
# profile
# 28911768    [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 138873847   [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 145809895   [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 398479964   [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 414139192   [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 566945301   [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 725055708   [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 866223830   [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 987686564   [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 1228480942  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 1334542814  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 1411880569  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 1544777819  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 1555372682  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 1717221219  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 1795197380  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 2172883580  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 2349877696  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 2359956581  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 2519980046  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 2579055440  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 2730693273  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 2863096306  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 2889946342  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 2952006503  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 2981673489  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 3075663633  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 3106592697  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 3113764014  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 3349665014  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 3393644004  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 3628762412  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 3661199063  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 3718772862  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
# 4153930878  [/scratch/group/csce435-f23/Caliper-CUDA/calip...
#
#                                     cmdline cluster    Algorithm  \
# profile
# 28911768       [./bitonic, 64, 67108864, 0]       g  BitonicSort
# 138873847     [./bitonic, 1024, 1048576, 0]       g  BitonicSort
# 145809895      [./bitonic, 128, 1048576, 0]       g  BitonicSort
# 398479964       [./bitonic, 256, 262144, 0]       g  BitonicSort
# 414139192       [./bitonic, 128, 262144, 0]       g  BitonicSort
# 566945301     [./bitonic, 1024, 4194304, 0]       g  BitonicSort
# 725055708     [./bitonic, 512, 67108864, 0]       g  BitonicSort
# 866223830     [./bitonic, 128, 67108864, 0]       g  BitonicSort
# 987686564        [./bitonic, 256, 65536, 0]       g  BitonicSort
# 1228480942     [./bitonic, 128, 4194304, 0]       g  BitonicSort
# 1334542814       [./bitonic, 128, 65536, 0]       g  BitonicSort
# 1411880569      [./bitonic, 512, 262144, 0]       g  BitonicSort
# 1544777819      [./bitonic, 64, 1048576, 0]       g  BitonicSort
# 1555372682     [./bitonic, 256, 4194304, 0]       g  BitonicSort
# 1717221219      [./bitonic, 64, 4194304, 0]       g  BitonicSort
# 1795197380  [./bitonic, 1024, 268435456, 0]       g  BitonicSort
# 2172883580    [./bitonic, 256, 16777216, 0]       g  BitonicSort
# 2349877696    [./bitonic, 128, 16777216, 0]       g  BitonicSort
# 2359956581   [./bitonic, 1024, 67108864, 0]       g  BitonicSort
# 2519980046   [./bitonic, 1024, 16777216, 0]       g  BitonicSort
# 2579055440   [./bitonic, 128, 268435456, 0]       g  BitonicSort
# 2730693273     [./bitonic, 64, 16777216, 0]       g  BitonicSort
# 2863096306     [./bitonic, 512, 1048576, 0]       g  BitonicSort
# 2889946342     [./bitonic, 512, 4194304, 0]       g  BitonicSort
# 2952006503   [./bitonic, 512, 268435456, 0]       g  BitonicSort
# 2981673489    [./bitonic, 512, 16777216, 0]       g  BitonicSort
# 3075663633       [./bitonic, 512, 65536, 0]       g  BitonicSort
# 3106592697    [./bitonic, 256, 67108864, 0]       g  BitonicSort
# 3113764014        [./bitonic, 64, 65536, 0]       g  BitonicSort
# 3349665014       [./bitonic, 64, 262144, 0]       g  BitonicSort
# 3393644004     [./bitonic, 1024, 262144, 0]       g  BitonicSort
# 3628762412    [./bitonic, 64, 268435456, 0]       g  BitonicSort
# 3661199063      [./bitonic, 1024, 65536, 0]       g  BitonicSort
# 3718772862     [./bitonic, 256, 1048576, 0]       g  BitonicSort
# 4153930878   [./bitonic, 256, 268435456, 0]       g  BitonicSort
#
#            ProgrammingModel Datatype  SizeOfDatatype  InputSize InputType  \
# profile
# 28911768               CUDA   double               8   67108864    Random
# 138873847              CUDA   double               8    1048576    Random
# 145809895              CUDA   double               8    1048576    Random
# 398479964              CUDA   double               8     262144    Random
# 414139192              CUDA   double               8     262144    Random
# 566945301              CUDA   double               8    4194304    Random
# 725055708              CUDA   double               8   67108864    Random
# 866223830              CUDA   double               8   67108864    Random
# 987686564              CUDA   double               8      65536    Random
# 1228480942             CUDA   double               8    4194304    Random
# 1334542814             CUDA   double               8      65536    Random
# 1411880569             CUDA   double               8     262144    Random
# 1544777819             CUDA   double               8    1048576    Random
# 1555372682             CUDA   double               8    4194304    Random
# 1717221219             CUDA   double               8    4194304    Random
# 1795197380             CUDA   double               8  268435456    Random
# 2172883580             CUDA   double               8   16777216    Random
# 2349877696             CUDA   double               8   16777216    Random
# 2359956581             CUDA   double               8   67108864    Random
# 2519980046             CUDA   double               8   16777216    Random
# 2579055440             CUDA   double               8  268435456    Random
# 2730693273             CUDA   double               8   16777216    Random
# 2863096306             CUDA   double               8    1048576    Random
# 2889946342             CUDA   double               8    4194304    Random
# 2952006503             CUDA   double               8  268435456    Random
# 2981673489             CUDA   double               8   16777216    Random
# 3075663633             CUDA   double               8      65536    Random
# 3106592697             CUDA   double               8   67108864    Random
# 3113764014             CUDA   double               8      65536    Random
# 3349665014             CUDA   double               8     262144    Random
# 3393644004             CUDA   double               8     262144    Random
# 3628762412             CUDA   double               8  268435456    Random
# 3661199063             CUDA   double               8      65536    Random
# 3718772862             CUDA   double               8    1048576    Random
# 4153930878             CUDA   double               8  268435456    Random
#
#             num_procs  group_num implementation_source
# profile
# 28911768           64         23    Online/Handwritten
# 138873847        1024         23    Online/Handwritten
# 145809895         128         23    Online/Handwritten
# 398479964         256         23    Online/Handwritten
# 414139192         128         23    Online/Handwritten
# 566945301        1024         23    Online/Handwritten
# 725055708         512         23    Online/Handwritten
# 866223830         128         23    Online/Handwritten
# 987686564         256         23    Online/Handwritten
# 1228480942        128         23    Online/Handwritten
# 1334542814        128         23    Online/Handwritten
# 1411880569        512         23    Online/Handwritten
# 1544777819         64         23    Online/Handwritten
# 1555372682        256         23    Online/Handwritten
# 1717221219         64         23    Online/Handwritten
# 1795197380       1024         23    Online/Handwritten
# 2172883580        256         23    Online/Handwritten
# 2349877696        128         23    Online/Handwritten
# 2359956581       1024         23    Online/Handwritten
# 2519980046       1024         23    Online/Handwritten
# 2579055440        128         23    Online/Handwritten
# 2730693273         64         23    Online/Handwritten
# 2863096306        512         23    Online/Handwritten
# 2889946342        512         23    Online/Handwritten
# 2952006503        512         23    Online/Handwritten
# 2981673489        512         23    Online/Handwritten
# 3075663633        512         23    Online/Handwritten
# 3106592697        256         23    Online/Handwritten
# 3113764014         64         23    Online/Handwritten
# 3349665014         64         23    Online/Handwritten
# 3393644004       1024         23    Online/Handwritten
# 3628762412         64         23    Online/Handwritten
# 3661199063       1024         23    Online/Handwritten
# 3718772862        256         23    Online/Handwritten
# 4153930878        256         23    Online/Handwritten

# %%
# Weak scaling: num_processes vs execution_time
gb = tk.groupby("InputSize")
# Out:
# 7  thickets created...
# {65536: <thicket.thicket.Thicket object at 0x0000020204EEEDD0>, 262144: <thicket.thicket.Thicket object at 0x00000202038DDDD0>, 1048576: <thicket.thicket.Thicket object at 0x0000020204776A50>, 4194304: <thicket.thicket.Thicket object at 0x0000020204DE6390>, 16777216: <thicket.thicket.Thicket object at 0x0000020204EDF0D0>, 67108864: <thicket.thicket.Thicket object at 0x0000020204E67D90>, 268435456: <thicket.thicket.Thicket object at 0x0000020204689910>}

# %%
ctk = th.Thicket.concat_thickets(
  thickets=list(gb.values()),
  headers=list(gb.keys()),
  axis="columns",
  metadata_key="num_procs"
)

# %%
ctk.dataframe
# Out:
#                                                              65536  \
#                                                                nid
# node                                               num_procs
# {'name': 'correct_check', 'type': 'function'}      64           11
#                                                    128          11
#                                                    256          11
#                                                    512          11
#                                                    1024         11
# {'name': 'data_init', 'type': 'function'}          64            1
#                                                    128           1
#                                                    256           1
#                                                    512           1
#                                                    1024          1
# {'name': 'main', 'type': 'function'}               64            3
#                                                    128           3
#                                                    256           3
#                                                    512           3
#                                                    1024          3
# {'name': 'bitonic_sort_step', 'type': 'function'}  64            6
#                                                    128           6
#                                                    256           6
#                                                    512           6
#                                                    1024          6
# {'name': 'comp_large', 'type': 'function'}         64            7
#                                                    128           7
#                                                    256           7
#                                                    512           7
#                                                    1024          7
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64            8
#                                                    128           8
#                                                    256           8
#                                                    512           8
#                                                    1024          8
# {'name': 'comm_small_2', 'type': 'function'}       64            9
#                                                    128           9
#                                                    256           9
#                                                    512           9
#                                                    1024          9
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64            4
#                                                    128           4
#                                                    256           4
#                                                    512           4
#                                                    1024          4
# {'name': 'comm_small_1', 'type': 'function'}       64            5
#                                                    128           5
#                                                    256           5
#                                                    512           5
#                                                    1024          5
#
#                                                                              \
#                                                                spot.channel
# node                                               num_procs
# {'name': 'correct_check', 'type': 'function'}      64         regionprofile
#                                                    128        regionprofile
#                                                    256        regionprofile
#                                                    512        regionprofile
#                                                    1024       regionprofile
# {'name': 'data_init', 'type': 'function'}          64         regionprofile
#                                                    128        regionprofile
#                                                    256        regionprofile
#                                                    512        regionprofile
#                                                    1024       regionprofile
# {'name': 'main', 'type': 'function'}               64         regionprofile
#                                                    128        regionprofile
#                                                    256        regionprofile
#                                                    512        regionprofile
#                                                    1024       regionprofile
# {'name': 'bitonic_sort_step', 'type': 'function'}  64         regionprofile
#                                                    128        regionprofile
#                                                    256        regionprofile
#                                                    512        regionprofile
#                                                    1024       regionprofile
# {'name': 'comp_large', 'type': 'function'}         64         regionprofile
#                                                    128        regionprofile
#                                                    256        regionprofile
#                                                    512        regionprofile
#                                                    1024       regionprofile
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64         regionprofile
#                                                    128        regionprofile
#                                                    256        regionprofile
#                                                    512        regionprofile
#                                                    1024       regionprofile
# {'name': 'comm_small_2', 'type': 'function'}       64         regionprofile
#                                                    128        regionprofile
#                                                    256        regionprofile
#                                                    512        regionprofile
#                                                    1024       regionprofile
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64         regionprofile
#                                                    128        regionprofile
#                                                    256        regionprofile
#                                                    512        regionprofile
#                                                    1024       regionprofile
# {'name': 'comm_small_1', 'type': 'function'}       64         regionprofile
#                                                    128        regionprofile
#                                                    256        regionprofile
#                                                    512        regionprofile
#                                                    1024       regionprofile
#
#                                                                             \
#                                                              Min time/rank
# node                                               num_procs
# {'name': 'correct_check', 'type': 'function'}      64             0.000179
#                                                    128            0.000192
#                                                    256            0.000182
#                                                    512            0.000182
#                                                    1024           0.000181
# {'name': 'data_init', 'type': 'function'}          64             0.000818
#                                                    128            0.000815
#                                                    256            0.000810
#                                                    512            0.000817
#                                                    1024           0.000865
# {'name': 'main', 'type': 'function'}               64             0.314576
#                                                    128            0.327970
#                                                    256            0.307202
#                                                    512            0.322623
#                                                    1024           0.325309
# {'name': 'bitonic_sort_step', 'type': 'function'}  64             0.000811
#                                                    128            0.000678
#                                                    256            0.000657
#                                                    512            0.000639
#                                                    1024           0.000763
# {'name': 'comp_large', 'type': 'function'}         64             0.000380
#                                                    128            0.000430
#                                                    256            0.000362
#                                                    512            0.000426
#                                                    1024           0.000386
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64             0.000098
#                                                    128            0.000115
#                                                    256            0.000102
#                                                    512            0.000107
#                                                    1024           0.000096
# {'name': 'comm_small_2', 'type': 'function'}       64             0.000088
#                                                    128            0.000099
#                                                    256            0.000092
#                                                    512            0.000097
#                                                    1024           0.000088
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64             0.000183
#                                                    128            0.000218
#                                                    256            0.000181
#                                                    512            0.000178
#                                                    1024           0.000199
# {'name': 'comm_small_1', 'type': 'function'}       64             0.000150
#                                                    128            0.000183
#                                                    256            0.000148
#                                                    512            0.000146
#                                                    1024           0.000167
#
#                                                                             \
#                                                              Max time/rank
# node                                               num_procs
# {'name': 'correct_check', 'type': 'function'}      64             0.000179
#                                                    128            0.000192
#                                                    256            0.000182
#                                                    512            0.000182
#                                                    1024           0.000181
# {'name': 'data_init', 'type': 'function'}          64             0.000818
#                                                    128            0.000815
#                                                    256            0.000810
#                                                    512            0.000817
#                                                    1024           0.000865
# {'name': 'main', 'type': 'function'}               64             0.314576
#                                                    128            0.327970
#                                                    256            0.307202
#                                                    512            0.322623
#                                                    1024           0.325309
# {'name': 'bitonic_sort_step', 'type': 'function'}  64             0.000811
#                                                    128            0.000678
#                                                    256            0.000657
#                                                    512            0.000639
#                                                    1024           0.000763
# {'name': 'comp_large', 'type': 'function'}         64             0.000380
#                                                    128            0.000430
#                                                    256            0.000362
#                                                    512            0.000426
#                                                    1024           0.000386
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64             0.000098
#                                                    128            0.000115
#                                                    256            0.000102
#                                                    512            0.000107
#                                                    1024           0.000096
# {'name': 'comm_small_2', 'type': 'function'}       64             0.000088
#                                                    128            0.000099
#                                                    256            0.000092
#                                                    512            0.000097
#                                                    1024           0.000088
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64             0.000183
#                                                    128            0.000218
#                                                    256            0.000181
#                                                    512            0.000178
#                                                    1024           0.000199
# {'name': 'comm_small_1', 'type': 'function'}       64             0.000150
#                                                    128            0.000183
#                                                    256            0.000148
#                                                    512            0.000146
#                                                    1024           0.000167
#
#                                                                             \
#                                                              Avg time/rank
# node                                               num_procs
# {'name': 'correct_check', 'type': 'function'}      64             0.000179
#                                                    128            0.000192
#                                                    256            0.000182
#                                                    512            0.000182
#                                                    1024           0.000181
# {'name': 'data_init', 'type': 'function'}          64             0.000818
#                                                    128            0.000815
#                                                    256            0.000810
#                                                    512            0.000817
#                                                    1024           0.000865
# {'name': 'main', 'type': 'function'}               64             0.314576
#                                                    128            0.327970
#                                                    256            0.307202
#                                                    512            0.322623
#                                                    1024           0.325309
# {'name': 'bitonic_sort_step', 'type': 'function'}  64             0.000811
#                                                    128            0.000678
#                                                    256            0.000657
#                                                    512            0.000639
#                                                    1024           0.000763
# {'name': 'comp_large', 'type': 'function'}         64             0.000380
#                                                    128            0.000430
#                                                    256            0.000362
#                                                    512            0.000426
#                                                    1024           0.000386
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64             0.000098
#                                                    128            0.000115
#                                                    256            0.000102
#                                                    512            0.000107
#                                                    1024           0.000096
# {'name': 'comm_small_2', 'type': 'function'}       64             0.000088
#                                                    128            0.000099
#                                                    256            0.000092
#                                                    512            0.000097
#                                                    1024           0.000088
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64             0.000183
#                                                    128            0.000218
#                                                    256            0.000181
#                                                    512            0.000178
#                                                    1024           0.000199
# {'name': 'comm_small_1', 'type': 'function'}       64             0.000150
#                                                    128            0.000183
#                                                    256            0.000148
#                                                    512            0.000146
#                                                    1024           0.000167
#
#                                                                          \
#                                                              Total time
# node                                               num_procs
# {'name': 'correct_check', 'type': 'function'}      64          0.000179
#                                                    128         0.000192
#                                                    256         0.000182
#                                                    512         0.000182
#                                                    1024        0.000181
# {'name': 'data_init', 'type': 'function'}          64          0.000818
#                                                    128         0.000815
#                                                    256         0.000810
#                                                    512         0.000817
#                                                    1024        0.000865
# {'name': 'main', 'type': 'function'}               64          0.314576
#                                                    128         0.327970
#                                                    256         0.307202
#                                                    512         0.322623
#                                                    1024        0.325309
# {'name': 'bitonic_sort_step', 'type': 'function'}  64          0.000811
#                                                    128         0.000678
#                                                    256         0.000657
#                                                    512         0.000639
#                                                    1024        0.000763
# {'name': 'comp_large', 'type': 'function'}         64          0.000380
#                                                    128         0.000430
#                                                    256         0.000362
#                                                    512         0.000426
#                                                    1024        0.000386
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64          0.000098
#                                                    128         0.000115
#                                                    256         0.000102
#                                                    512         0.000107
#                                                    1024        0.000096
# {'name': 'comm_small_2', 'type': 'function'}       64          0.000088
#                                                    128         0.000099
#                                                    256         0.000092
#                                                    512         0.000097
#                                                    1024        0.000088
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64          0.000183
#                                                    128         0.000218
#                                                    256         0.000181
#                                                    512         0.000178
#                                                    1024        0.000199
# {'name': 'comm_small_1', 'type': 'function'}       64          0.000150
#                                                    128         0.000183
#                                                    256         0.000148
#                                                    512         0.000146
#                                                    1024        0.000167
#
#                                                              262144  \
#                                                                 nid
# node                                               num_procs
# {'name': 'correct_check', 'type': 'function'}      64            11
#                                                    128           11
#                                                    256           11
#                                                    512           11
#                                                    1024          11
# {'name': 'data_init', 'type': 'function'}          64             1
#                                                    128            1
#                                                    256            1
#                                                    512            1
#                                                    1024           1
# {'name': 'main', 'type': 'function'}               64             3
#                                                    128            3
#                                                    256            3
#                                                    512            3
#                                                    1024           3
# {'name': 'bitonic_sort_step', 'type': 'function'}  64             6
#                                                    128            6
#                                                    256            6
#                                                    512            6
#                                                    1024           6
# {'name': 'comp_large', 'type': 'function'}         64             7
#                                                    128            7
#                                                    256            7
#                                                    512            7
#                                                    1024           7
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64             8
#                                                    128            8
#                                                    256            8
#                                                    512            8
#                                                    1024           8
# {'name': 'comm_small_2', 'type': 'function'}       64             9
#                                                    128            9
#                                                    256            9
#                                                    512            9
#                                                    1024           9
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64             4
#                                                    128            4
#                                                    256            4
#                                                    512            4
#                                                    1024           4
# {'name': 'comm_small_1', 'type': 'function'}       64             5
#                                                    128            5
#                                                    256            5
#                                                    512            5
#                                                    1024           5
#
#                                                                              \
#                                                                spot.channel
# node                                               num_procs
# {'name': 'correct_check', 'type': 'function'}      64         regionprofile
#                                                    128        regionprofile
#                                                    256        regionprofile
#                                                    512        regionprofile
#                                                    1024       regionprofile
# {'name': 'data_init', 'type': 'function'}          64         regionprofile
#                                                    128        regionprofile
#                                                    256        regionprofile
#                                                    512        regionprofile
#                                                    1024       regionprofile
# {'name': 'main', 'type': 'function'}               64         regionprofile
#                                                    128        regionprofile
#                                                    256        regionprofile
#                                                    512        regionprofile
#                                                    1024       regionprofile
# {'name': 'bitonic_sort_step', 'type': 'function'}  64         regionprofile
#                                                    128        regionprofile
#                                                    256        regionprofile
#                                                    512        regionprofile
#                                                    1024       regionprofile
# {'name': 'comp_large', 'type': 'function'}         64         regionprofile
#                                                    128        regionprofile
#                                                    256        regionprofile
#                                                    512        regionprofile
#                                                    1024       regionprofile
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64         regionprofile
#                                                    128        regionprofile
#                                                    256        regionprofile
#                                                    512        regionprofile
#                                                    1024       regionprofile
# {'name': 'comm_small_2', 'type': 'function'}       64         regionprofile
#                                                    128        regionprofile
#                                                    256        regionprofile
#                                                    512        regionprofile
#                                                    1024       regionprofile
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64         regionprofile
#                                                    128        regionprofile
#                                                    256        regionprofile
#                                                    512        regionprofile
#                                                    1024       regionprofile
# {'name': 'comm_small_1', 'type': 'function'}       64         regionprofile
#                                                    128        regionprofile
#                                                    256        regionprofile
#                                                    512        regionprofile
#                                                    1024       regionprofile
#
#                                                                             \
#                                                              Min time/rank
# node                                               num_procs
# {'name': 'correct_check', 'type': 'function'}      64             0.000746
#                                                    128            0.000773
#                                                    256            0.000770
#                                                    512            0.000803
#                                                    1024           0.000908
# {'name': 'data_init', 'type': 'function'}          64             0.003138
#                                                    128            0.003063
#                                                    256            0.003229
#                                                    512            0.003085
#                                                    1024           0.003188
# {'name': 'main', 'type': 'function'}               64             0.328985
#                                                    128            0.325893
#                                                    256            0.319444
#                                                    512            0.586438
#                                                    1024           0.596840
# {'name': 'bitonic_sort_step', 'type': 'function'}  64             0.001585
#                                                    128            0.001399
#                                                    256            0.000901
#                                                    512            0.001141
#                                                    1024           0.001194
# {'name': 'comp_large', 'type': 'function'}         64             0.000477
#                                                    128            0.000566
#                                                    256            0.000514
#                                                    512            0.000572
#                                                    1024           0.000504
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64             0.000297
#                                                    128            0.000320
#                                                    256            0.000306
#                                                    512            0.000327
#                                                    1024           0.000307
# {'name': 'comm_small_2', 'type': 'function'}       64             0.000287
#                                                    128            0.000306
#                                                    256            0.000293
#                                                    512            0.000312
#                                                    1024           0.000294
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64             0.000433
#                                                    128            0.000477
#                                                    256            0.000430
#                                                    512            0.000430
#                                                    1024           0.000428
# {'name': 'comm_small_1', 'type': 'function'}       64             0.000398
#                                                    128            0.000440
#                                                    256            0.000396
#                                                    512            0.000393
#                                                    1024           0.000393
#
#                                                                             \
#                                                              Max time/rank
# node                                               num_procs
# {'name': 'correct_check', 'type': 'function'}      64             0.000746
#                                                    128            0.000773
#                                                    256            0.000770
#                                                    512            0.000803
#                                                    1024           0.000908
# {'name': 'data_init', 'type': 'function'}          64             0.003138
#                                                    128            0.003063
#                                                    256            0.003229
#                                                    512            0.003085
#                                                    1024           0.003188
# {'name': 'main', 'type': 'function'}               64             0.328985
#                                                    128            0.325893
#                                                    256            0.319444
#                                                    512            0.586438
#                                                    1024           0.596840
# {'name': 'bitonic_sort_step', 'type': 'function'}  64             0.001585
#                                                    128            0.001399
#                                                    256            0.000901
#                                                    512            0.001141
#                                                    1024           0.001194
# {'name': 'comp_large', 'type': 'function'}         64             0.000477
#                                                    128            0.000566
#                                                    256            0.000514
#                                                    512            0.000572
#                                                    1024           0.000504
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64             0.000297
#                                                    128            0.000320
#                                                    256            0.000306
#                                                    512            0.000327
#                                                    1024           0.000307
# {'name': 'comm_small_2', 'type': 'function'}       64             0.000287
#                                                    128            0.000306
#                                                    256            0.000293
#                                                    512            0.000312
#                                                    1024           0.000294
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64             0.000433
#                                                    128            0.000477
#                                                    256            0.000430
#                                                    512            0.000430
#                                                    1024           0.000428
# {'name': 'comm_small_1', 'type': 'function'}       64             0.000398
#                                                    128            0.000440
#                                                    256            0.000396
#                                                    512            0.000393
#                                                    1024           0.000393
#
#                                                                             \
#                                                              Avg time/rank
# node                                               num_procs
# {'name': 'correct_check', 'type': 'function'}      64             0.000746
#                                                    128            0.000773
#                                                    256            0.000770
#                                                    512            0.000803
#                                                    1024           0.000908
# {'name': 'data_init', 'type': 'function'}          64             0.003138
#                                                    128            0.003063
#                                                    256            0.003229
#                                                    512            0.003085
#                                                    1024           0.003188
# {'name': 'main', 'type': 'function'}               64             0.328985
#                                                    128            0.325893
#                                                    256            0.319444
#                                                    512            0.586438
#                                                    1024           0.596840
# {'name': 'bitonic_sort_step', 'type': 'function'}  64             0.001585
#                                                    128            0.001399
#                                                    256            0.000901
#                                                    512            0.001141
#                                                    1024           0.001194
# {'name': 'comp_large', 'type': 'function'}         64             0.000477
#                                                    128            0.000566
#                                                    256            0.000514
#                                                    512            0.000572
#                                                    1024           0.000504
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64             0.000297
#                                                    128            0.000320
#                                                    256            0.000306
#                                                    512            0.000327
#                                                    1024           0.000307
# {'name': 'comm_small_2', 'type': 'function'}       64             0.000287
#                                                    128            0.000306
#                                                    256            0.000293
#                                                    512            0.000312
#                                                    1024           0.000294
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64             0.000433
#                                                    128            0.000477
#                                                    256            0.000430
#                                                    512            0.000430
#                                                    1024           0.000428
# {'name': 'comm_small_1', 'type': 'function'}       64             0.000398
#                                                    128            0.000440
#                                                    256            0.000396
#                                                    512            0.000393
#                                                    1024           0.000393
#
#                                                                          \
#                                                              Total time
# node                                               num_procs
# {'name': 'correct_check', 'type': 'function'}      64          0.000746
#                                                    128         0.000773
#                                                    256         0.000770
#                                                    512         0.000803
#                                                    1024        0.000908
# {'name': 'data_init', 'type': 'function'}          64          0.003138
#                                                    128         0.003063
#                                                    256         0.003229
#                                                    512         0.003085
#                                                    1024        0.003188
# {'name': 'main', 'type': 'function'}               64          0.328985
#                                                    128         0.325893
#                                                    256         0.319444
#                                                    512         0.586438
#                                                    1024        0.596840
# {'name': 'bitonic_sort_step', 'type': 'function'}  64          0.001585
#                                                    128         0.001399
#                                                    256         0.000901
#                                                    512         0.001141
#                                                    1024        0.001194
# {'name': 'comp_large', 'type': 'function'}         64          0.000477
#                                                    128         0.000566
#                                                    256         0.000514
#                                                    512         0.000572
#                                                    1024        0.000504
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64          0.000297
#                                                    128         0.000320
#                                                    256         0.000306
#                                                    512         0.000327
#                                                    1024        0.000307
# {'name': 'comm_small_2', 'type': 'function'}       64          0.000287
#                                                    128         0.000306
#                                                    256         0.000293
#                                                    512         0.000312
#                                                    1024        0.000294
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64          0.000433
#                                                    128         0.000477
#                                                    256         0.000430
#                                                    512         0.000430
#                                                    1024        0.000428
# {'name': 'comm_small_1', 'type': 'function'}       64          0.000398
#                                                    128         0.000440
#                                                    256         0.000396
#                                                    512         0.000393
#                                                    1024        0.000393
#
#                                                              1048576  \
#                                                                  nid
# node                                               num_procs
# {'name': 'correct_check', 'type': 'function'}      64             11
#                                                    128            11
#                                                    256            11
#                                                    512            11
#                                                    1024           11
# {'name': 'data_init', 'type': 'function'}          64              1
#                                                    128             1
#                                                    256             1
#                                                    512             1
#                                                    1024            1
# {'name': 'main', 'type': 'function'}               64              3
#                                                    128             3
#                                                    256             3
#                                                    512             3
#                                                    1024            3
# {'name': 'bitonic_sort_step', 'type': 'function'}  64              6
#                                                    128             6
#                                                    256             6
#                                                    512             6
#                                                    1024            6
# {'name': 'comp_large', 'type': 'function'}         64              7
#                                                    128             7
#                                                    256             7
#                                                    512             7
#                                                    1024            7
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64              8
#                                                    128             8
#                                                    256             8
#                                                    512             8
#                                                    1024            8
# {'name': 'comm_small_2', 'type': 'function'}       64              9
#                                                    128             9
#                                                    256             9
#                                                    512             9
#                                                    1024            9
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64              4
#                                                    128             4
#                                                    256             4
#                                                    512             4
#                                                    1024            4
# {'name': 'comm_small_1', 'type': 'function'}       64              5
#                                                    128             5
#                                                    256             5
#                                                    512             5
#                                                    1024            5
#
#                                                                              \
#                                                                spot.channel
# node                                               num_procs
# {'name': 'correct_check', 'type': 'function'}      64         regionprofile
#                                                    128        regionprofile
#                                                    256        regionprofile
# ...
#                                                    512            0.226535
#                                                    1024           0.228490
# {'name': 'comm_small_1', 'type': 'function'}       64             0.226443
#                                                    128            0.229717
#                                                    256            0.229049
#                                                    512            0.226495
#                                                    1024           0.228452
#
#                                                                             \
#                                                              Max time/rank
# node                                               num_procs
# {'name': 'correct_check', 'type': 'function'}      64             0.703279
#                                                    128            0.698580
#                                                    256            0.705936
#                                                    512            0.701796
#                                                    1024           0.701766
# {'name': 'data_init', 'type': 'function'}          64             2.902184
#                                                    128            2.903481
#                                                    256            2.899954
#                                                    512            2.904060
#                                                    1024           2.903459
# {'name': 'main', 'type': 'function'}               64             2.104657
#                                                    128            1.785871
#                                                    256            1.605558
#                                                    512            1.325233
#                                                    1024           1.384385
# {'name': 'bitonic_sort_step', 'type': 'function'}  64             1.330713
#                                                    128            0.733933
#                                                    256            0.575802
#                                                    512            0.563594
#                                                    1024           0.593300
# {'name': 'comp_large', 'type': 'function'}         64             0.000949
#                                                    128            0.000996
#                                                    256            0.000961
#                                                    512            0.001008
#                                                    1024           0.001030
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64             0.225918
#                                                    128            0.237078
#                                                    256            0.226347
#                                                    512            0.223552
#                                                    1024           0.236923
# {'name': 'comm_small_2', 'type': 'function'}       64             0.225898
#                                                    128            0.237058
#                                                    256            0.226331
#                                                    512            0.223534
#                                                    1024           0.236908
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64             0.226478
#                                                    128            0.229759
#                                                    256            0.229082
#                                                    512            0.226535
#                                                    1024           0.228490
# {'name': 'comm_small_1', 'type': 'function'}       64             0.226443
#                                                    128            0.229717
#                                                    256            0.229049
#                                                    512            0.226495
#                                                    1024           0.228452
#
#                                                                             \
#                                                              Avg time/rank
# node                                               num_procs
# {'name': 'correct_check', 'type': 'function'}      64             0.703279
#                                                    128            0.698580
#                                                    256            0.705936
#                                                    512            0.701796
#                                                    1024           0.701766
# {'name': 'data_init', 'type': 'function'}          64             2.902184
#                                                    128            2.903481
#                                                    256            2.899954
#                                                    512            2.904060
#                                                    1024           2.903459
# {'name': 'main', 'type': 'function'}               64             2.104657
#                                                    128            1.785871
#                                                    256            1.605558
#                                                    512            1.325233
#                                                    1024           1.384385
# {'name': 'bitonic_sort_step', 'type': 'function'}  64             1.330713
#                                                    128            0.733933
#                                                    256            0.575802
#                                                    512            0.563594
#                                                    1024           0.593300
# {'name': 'comp_large', 'type': 'function'}         64             0.000949
#                                                    128            0.000996
#                                                    256            0.000961
#                                                    512            0.001008
#                                                    1024           0.001030
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64             0.225918
#                                                    128            0.237078
#                                                    256            0.226347
#                                                    512            0.223552
#                                                    1024           0.236923
# {'name': 'comm_small_2', 'type': 'function'}       64             0.225898
#                                                    128            0.237058
#                                                    256            0.226331
#                                                    512            0.223534
#                                                    1024           0.236908
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64             0.226478
#                                                    128            0.229759
#                                                    256            0.229082
#                                                    512            0.226535
#                                                    1024           0.228490
# {'name': 'comm_small_1', 'type': 'function'}       64             0.226443
#                                                    128            0.229717
#                                                    256            0.229049
#                                                    512            0.226495
#                                                    1024           0.228452
#
#                                                                          \
#                                                              Total time
# node                                               num_procs
# {'name': 'correct_check', 'type': 'function'}      64          0.703279
#                                                    128         0.698580
#                                                    256         0.705936
#                                                    512         0.701796
#                                                    1024        0.701766
# {'name': 'data_init', 'type': 'function'}          64          2.902184
#                                                    128         2.903481
#                                                    256         2.899954
#                                                    512         2.904060
#                                                    1024        2.903459
# {'name': 'main', 'type': 'function'}               64          2.104657
#                                                    128         1.785871
#                                                    256         1.605558
#                                                    512         1.325233
#                                                    1024        1.384385
# {'name': 'bitonic_sort_step', 'type': 'function'}  64          1.330713
#                                                    128         0.733933
#                                                    256         0.575802
#                                                    512         0.563594
#                                                    1024        0.593300
# {'name': 'comp_large', 'type': 'function'}         64          0.000949
#                                                    128         0.000996
#                                                    256         0.000961
#                                                    512         0.001008
#                                                    1024        0.001030
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64          0.225918
#                                                    128         0.237078
#                                                    256         0.226347
#                                                    512         0.223552
#                                                    1024        0.236923
# {'name': 'comm_small_2', 'type': 'function'}       64          0.225898
#                                                    128         0.237058
#                                                    256         0.226331
#                                                    512         0.223534
#                                                    1024        0.236908
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64          0.226478
#                                                    128         0.229759
#                                                    256         0.229082
#                                                    512         0.226535
#                                                    1024        0.228490
# {'name': 'comm_small_1', 'type': 'function'}       64          0.226443
#                                                    128         0.229717
#                                                    256         0.229049
#                                                    512         0.226495
#                                                    1024        0.228452
#
#                                                                                    name
#
# node                                               num_procs
# {'name': 'correct_check', 'type': 'function'}      64                     correct_check
#                                                    128                    correct_check
#                                                    256                    correct_check
#                                                    512                    correct_check
#                                                    1024                   correct_check
# {'name': 'data_init', 'type': 'function'}          64                         data_init
#                                                    128                        data_init
#                                                    256                        data_init
#                                                    512                        data_init
#                                                    1024                       data_init
# {'name': 'main', 'type': 'function'}               64                              main
#                                                    128                             main
#                                                    256                             main
#                                                    512                             main
#                                                    1024                            main
# {'name': 'bitonic_sort_step', 'type': 'function'}  64                 bitonic_sort_step
#                                                    128                bitonic_sort_step
#                                                    256                bitonic_sort_step
#                                                    512                bitonic_sort_step
#                                                    1024               bitonic_sort_step
# {'name': 'comp_large', 'type': 'function'}         64                        comp_large
#                                                    128                       comp_large
#                                                    256                       comp_large
#                                                    512                       comp_large
#                                                    1024                      comp_large
# {'name': 'cudaMemcpy_device_to_host', 'type': '... 64         cudaMemcpy_device_to_host
#                                                    128        cudaMemcpy_device_to_host
#                                                    256        cudaMemcpy_device_to_host
#                                                    512        cudaMemcpy_device_to_host
#                                                    1024       cudaMemcpy_device_to_host
# {'name': 'comm_small_2', 'type': 'function'}       64                      comm_small_2
#                                                    128                     comm_small_2
#                                                    256                     comm_small_2
#                                                    512                     comm_small_2
#                                                    1024                    comm_small_2
# {'name': 'cudaMemcpy_host_to_device', 'type': '... 64         cudaMemcpy_host_to_device
#                                                    128        cudaMemcpy_host_to_device
#                                                    256        cudaMemcpy_host_to_device
#                                                    512        cudaMemcpy_host_to_device
#                                                    1024       cudaMemcpy_host_to_device
# {'name': 'comm_small_1', 'type': 'function'}       64                      comm_small_1
#                                                    128                     comm_small_1
#                                                    256                     comm_small_1
#                                                    512                     comm_small_1
#                                                    1024                    comm_small_1

# %%
dropTheseCol = ["nid", "spot.channel",  "Min time/rank", "Max time/rank", "Total time", "Variance time/rank"]
sizes = [65536, 262144, 1048576, 4194304, 16777216, 67108864, 268435456]
dropArr = [("node", "")]

for c in dropTheseCol:
    for s in sizes:
        dropArr.append((s, c))
    

ctk.dataframe = ctk.dataframe.reset_index().drop(dropArr, axis=1)

ctk.dataframe = ctk.dataframe.rename({("name", ""): "name",("mpi.world.size", ""): "mpi.world.size"}).set_index(["name", "mpi.world.size"])


ctk.dataframe
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\sofia\Code\ParallelComputingProject\venv\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Variance time/rank'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File index.pyx:842, in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# File c:\Users\sofia\Code\ParallelComputingProject\venv\Lib\site-packages\pandas\core\indexes\base.py:3797, in Index.get_loc(self, key)
#    3796         raise InvalidIndexError(key)
# -> 3797     raise KeyError(key) from err
#    3798 except TypeError:
#    3799     # If we have a listlike key, _check_indexing_error will raise
#    3800     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3801     #  the TypeError.
#
# KeyError: 'Variance time/rank'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File c:\Users\sofia\Code\ParallelComputingProject\venv\Lib\site-packages\pandas\core\indexes\multi.py:2938, in MultiIndex.get_loc(self, key)
#    2937 try:
# -> 2938     return self._engine.get_loc(key)
#    2939 except KeyError as err:
#
# File index.pyx:845, in pandas._libs.index.BaseMultiIndexCodesEngine.get_loc()
#
# KeyError: (65536, 'Variance time/rank')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# c:\Users\sofia\Code\ParallelComputingProject\PerformanceEval\strong_scaling.ipynb Cell 8 line 1
#       <a href='vscode-notebook-cell:/c%3A/Users/sofia/Code/ParallelComputingProject/PerformanceEval/strong_scaling.ipynb#X10sZmlsZQ%3D%3D?line=5'>6</a>     for s in sizes:
#       <a href='vscode-notebook-cell:/c%3A/Users/sofia/Code/ParallelComputingProject/PerformanceEval/strong_scaling.ipynb#X10sZmlsZQ%3D%3D?line=6'>7</a>         dropArr.append((s, c))
# ---> <a href='vscode-notebook-cell:/c%3A/Users/sofia/Code/ParallelComputingProject/PerformanceEval/strong_scaling.ipynb#X10sZmlsZQ%3D%3D?line=9'>10</a> ctk.dataframe = ctk.dataframe.reset_index().drop(dropArr, axis=1)
#      <a href='vscode-notebook-cell:/c%3A/Users/sofia/Code/ParallelComputingProject/PerformanceEval/strong_scaling.ipynb#X10sZmlsZQ%3D%3D?line=11'>12</a> ctk.dataframe = ctk.dataframe.rename({("name", ""): "name",("mpi.world.size", ""): "mpi.world.size"}).set_index(["name", "mpi.world.size"])
#      <a href='vscode-notebook-cell:/c%3A/Users/sofia/Code/ParallelComputingProject/PerformanceEval/strong_scaling.ipynb#X10sZmlsZQ%3D%3D?line=14'>15</a> ctk.dataframe
#
# File c:\Users\sofia\Code\ParallelComputingProject\venv\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File c:\Users\sofia\Code\ParallelComputingProject\venv\Lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File c:\Users\sofia\Code\ParallelComputingProject\venv\Lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File c:\Users\sofia\Code\ParallelComputingProject\venv\Lib\site-packages\pandas\core\indexes\multi.py:2304, in MultiIndex.drop(self, codes, level, errors)
#    2302 for level_codes in codes:
#    2303     try:
# -> 2304         loc = self.get_loc(level_codes)
#    2305         # get_loc returns either an integer, a slice, or a boolean
#    2306         # mask
#    2307         if isinstance(loc, int):
#
# File c:\Users\sofia\Code\ParallelComputingProject\venv\Lib\site-packages\pandas\core\indexes\multi.py:2940, in MultiIndex.get_loc(self, key)
#    2938     return self._engine.get_loc(key)
#    2939 except KeyError as err:
# -> 2940     raise KeyError(key) from err
#    2941 except TypeError:
#    2942     # e.g. test_partial_slicing_with_multiindex partial string slicing
#    2943     loc, _ = self.get_loc_level(key, list(range(self.nlevels)))
#
# KeyError: (65536, 'Variance time/rank')

# %%
function_names = set(ctk.dataframe.index.get_level_values("name"))
world_size = sorted(list(set(ctk.dataframe.index.get_level_values("mpi.world.size"))))
num_values = sorted(ctk.dataframe.columns.tolist())

print(function_names)
# Out:
# {'comm_large', 'comm', 'correctness_check', 'data_init', 'MPI_Barrier', 'MPI_Isend', 'comp_large', 'comm_small', 'MPI_Recv', 'main', 'comp'}

# %%
def plot_pandas(df, title, xlabel, ylabel, loglog, legend, legendTitle):
    plot = df.plot(kind="line",
                  marker='o',
                  title=title,
                  xlabel=xlabel,
                  ylabel=ylabel,
                  grid=True,
                  loglog=loglog
                )
    plot.legend(legend, title=legendTitle)
    return plot

# %%
ctk.dataframe.loc['main']
# Out:
#                        65536        262144       1048576       4194304  \
#                Avg time/rank Avg time/rank Avg time/rank Avg time/rank
# mpi.world.size
# 2                   0.542861      0.526884      0.558989      0.709285
# 4                   0.395139      0.380098      0.397349      0.514842
# 8                   0.537573      0.496468      0.522839      0.612121
# 16                  0.863317      0.873716      0.775181      0.807790
# 32                  1.622895      1.378789      1.397741      1.464846
# 64                  1.471126      1.365624      1.355660      1.380020
# 128                 1.834020      1.831568      1.861377      1.926827
# 256                 1.715446      1.744341      1.731115      1.717646
#
#                     16777216      67108864     268435456
#                Avg time/rank Avg time/rank Avg time/rank
# mpi.world.size
# 2                   1.238742      3.232949     14.030497
# 4                   0.720491      1.795407      6.138141
# 8                   0.699577      1.327733      4.908643
# 16                  0.910032           NaN      3.470717
# 32                  1.778626      2.081455           NaN
# 64                  1.410860      1.751085           NaN
# 128                 1.504696           NaN           NaN
# 256                 2.134516           NaN           NaN

# %%
function_names = {'comm', 'data_init', 'comp',  'main'}
function_names = {'main'}

# legend = [65536,262144,	1048576,	4194304,	16777216,	67108864,	268435456]
legend = []
for i in range(7):
  legend.append(f"2^{16 + (i * 2)} Input")

legendTitle = "Input Size"

for name in function_names:
  plot_pandas(
      df=ctk.dataframe.loc[name],
      title=f"{algorithm} {input_type} input: {name}",
      xlabel="Threads",
      ylabel="Time (seconds)",
      loglog=False,
      legend=legend,
      legendTitle=legendTitle
  )

# %%
tk2.statsframe.dataframe["test"] = -1
print(tk2.tree(metric_column="test"))
# Out:
#   _____ _     _      _        _
#  |_   _| |__ (_) ___| | _____| |_
#    | | | '_ \| |/ __| |/ / _ \ __|
#    | | | | | | | (__|   <  __/ |_
#    |_| |_| |_|_|\___|_|\_\___|\__|  v2023.3.1
#
# -1.000 main
# ├─ -1.000 comm
# │  └─ -1.000 comm_large
# │     └─ -1.000 cudaMemcpy
# ├─ -1.000 comp
# │  └─ -1.000 comp_large
# ├─ -1.000 correctness_check
# └─ -1.000 data_init
#
# Legend (Metric: test Min: -1.00 Max: -1.00)
# █ -1.00 - -1.00
# █ -1.00 - -1.00
# █ -1.00 - -1.00
# █ -1.00 - -1.00
# █ -1.00 - -1.00
# █ -1.00 - -1.00
#
# name User code    ◀  Only in left graph    ▶  Only in right graph
